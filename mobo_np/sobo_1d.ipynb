# %%
import numpy as np

# %% [markdown]
# 1d situation

# %%
noise = 1e-3
def f(X, noise=noise):
    return -np.sin(3*X) - X**2 + 0.7*X + noise * np.random.randn(*X.shape)
constrains = {'X': (-1.0, 2.0)}

# %% [markdown]
# optimization

# %%
from optim_process_sobo import optim_process
n_init = 5
n_iter = 10
optimizer_params = optim_process(f, constrains, noise, n_init=n_init, n_iter=n_iter)
optimizer_params.target
# Out:
# 0.5019193192331612

# %%
optimizer_params.params
# Out:
# {'X': -0.3611389783224511}
