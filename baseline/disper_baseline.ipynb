# %% [markdown]
# ### calculate the effective_dissipation_rate for teno5

# %% [markdown]
# initialization

# %%
import glob
import h5py
import json
target_folder_name = "imp/results/fullimplosion"

# %%
from imp.imp_postprocessing import calculate_epsilon_baseline
epsilon_baseline = calculate_epsilon_baseline(target_folder_name)
print(epsilon_baseline)
# Out:
# Load imp/results/fullimplosion/domain/data_2.5000644562.h5
# -1.4803669984900289e-05

# %% [markdown]
# plot

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.imshow(effective_dissipation_rate)
plt.colorbar()

plt.subplot(1,2,2)
plt.imshow(highorder_dissipation_rate)
plt.colorbar()

# %%
import numpy as np
adi_to_ref = - (effective_dissipation_rate - highorder_dissipation_rate)
epsilon_baseline = np.where(adi_to_ref < 0, adi_to_ref, 0).sum()
print(epsilon_baseline)
# Out:
# -1.4803669984900289e-05
